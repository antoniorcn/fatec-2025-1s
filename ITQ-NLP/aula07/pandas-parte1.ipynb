# %%
import pandas as pd

# %%
dados = { "peras": [10, 12, 5, 4, 6], "laranjas": [20, 24, 32, 16, 8] }

# %%
df = pd.DataFrame( dados ) 
df
# Out:
#    peras  laranjas
# 0     10        20
# 1     12        24
# 2      5        32
# 3      4        16
# 4      6         8

# %%
df = pd.DataFrame.from_dict( dados, orient="index" ) 
df
# Out:
#            0   1   2   3  4
# peras     10  12   5   4  6
# laranjas  20  24  32  16  8

# %%
df = pd.DataFrame.from_dict( dados, orient="index", columns=[ 'estoque_1', 'estoque_2', 
                                                             'estoque_3','estoque_4', 'estoque_5' ] ) 
df
# Out:
#           estoque_1  estoque_2  estoque_3  estoque_4  estoque_5
# peras            10         12          5          4          6
# laranjas         20         24         32         16          8

# %%
df = pd.read_csv( "../../../dados/nlp/news_sentiment_analysis.csv", encoding="utf-8")
df
# Out:
#                  Source           Author  \
# 0               stgnews   Bridger Palmer
# 1         Zimbabwe Mail   Staff Reporter
# 2             4-traders              NaN
# 3             4-traders              NaN
# 4                PLANET              NaN
# ...                 ...              ...
# 3495       etfdailynews  MarketBeat News
# 3496       etfdailynews  MarketBeat News
# 3497       etfdailynews  MarketBeat News
# 3498  finanznachrichten              NaN
# 3499       etfdailynews  MarketBeat News
#
#                                                   Title  \
# 0     Pine View High teacher wins Best in State awar...
# 1     Businesses Face Financial Strain Amid Liquidit...
# 2     Musk donates to super pac working to elect Tru...
# 3     US FTC issues warning to franchisors over unfa...
# 4                             Rooftop solar's dark side
# ...                                                 ...
# 3495  Arrow Electronics, Inc. (NYSE:ARW) Shares Purc...
# ...

# %%
df.head(10)
# Out:
#                             Source          Author  \
# 0                          stgnews  Bridger Palmer
# 1                    Zimbabwe Mail  Staff Reporter
# 2                        4-traders             NaN
# 3                        4-traders             NaN
# 4                           PLANET             NaN
# 5                        4-traders             NaN
# 6                        4-traders             NaN
# 7                        4-traders             NaN
# 8                    The Chronicle           peter
# 9  International Business Times Au             NaN
#
#                                                Title  \
# 0  Pine View High teacher wins Best in State awar...
# 1  Businesses Face Financial Strain Amid Liquidit...
# 2  Musk donates to super pac working to elect Tru...
# 3  US FTC issues warning to franchisors over unfa...
# 4                          Rooftop solar's dark side
# 5  Gabelli asks Paramount for details on National...
# ...

# %%
df.tail(10)
# Out:
#                                                  Source           Author  \
# 3490                                       etfdailynews  MarketBeat News
# 3491  Investing.com | Stock Market Quotes &amp; Fina...    Investing.com
# 3492                                  finanznachrichten              NaN
# 3493                                       etfdailynews  MarketBeat News
# 3494                                americanbankingnews       ABMN Staff
# 3495                                       etfdailynews  MarketBeat News
# 3496                                       etfdailynews  MarketBeat News
# 3497                                       etfdailynews  MarketBeat News
# 3498                                  finanznachrichten              NaN
# 3499                                       etfdailynews  MarketBeat News
#
#                                                   Title  \
# 3490  Russell Investments Group Ltd. Has $16.64 Mill...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Source        3500 non-null   object
#  1   Author        2512 non-null   object
#  2   Title         3500 non-null   object
#  3   Description   3500 non-null   object
#  4   URL           3500 non-null   object
#  5   Published At  3500 non-null   object
#  6   Sentiment     3500 non-null   object
#  7   Type          3500 non-null   object
# dtypes: object(8)
# memory usage: 218.9+ KB

# %%
df['Titulo_STR'] = df['Title'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Source        3500 non-null   object
#  1   Author        2512 non-null   object
#  2   Title         3500 non-null   object
#  3   Description   3500 non-null   object
#  4   URL           3500 non-null   object
#  5   Published At  3500 non-null   object
#  6   Sentiment     3500 non-null   object
#  7   Type          3500 non-null   object
#  8   Titulo_STR    3500 non-null   object
# dtypes: object(9)
# memory usage: 246.2+ KB

# %%
df.shape
# Out:
# (3500, 9)

# %%
df
# Out:
#                  Source           Author  \
# 0               stgnews   Bridger Palmer
# 1         Zimbabwe Mail   Staff Reporter
# 2             4-traders              NaN
# 3             4-traders              NaN
# 4                PLANET              NaN
# ...                 ...              ...
# 3495       etfdailynews  MarketBeat News
# 3496       etfdailynews  MarketBeat News
# 3497       etfdailynews  MarketBeat News
# 3498  finanznachrichten              NaN
# 3499       etfdailynews  MarketBeat News
#
#                                                   Title  \
# 0     Pine View High teacher wins Best in State awar...
# 1     Businesses Face Financial Strain Amid Liquidit...
# 2     Musk donates to super pac working to elect Tru...
# 3     US FTC issues warning to franchisors over unfa...
# 4                             Rooftop solar's dark side
# ...                                                 ...
# 3495  Arrow Electronics, Inc. (NYSE:ARW) Shares Purc...
# ...

# %%
df
# Out:
#                  Source           Author  \
# 0               stgnews   Bridger Palmer
# 1         Zimbabwe Mail   Staff Reporter
# 2             4-traders              NaN
# 3             4-traders              NaN
# 4                PLANET              NaN
# ...                 ...              ...
# 3495       etfdailynews  MarketBeat News
# 3496       etfdailynews  MarketBeat News
# 3497       etfdailynews  MarketBeat News
# 3498  finanznachrichten              NaN
# 3499       etfdailynews  MarketBeat News
#
#                                                   Title  \
# 0     Pine View High teacher wins Best in State awar...
# 1     Businesses Face Financial Strain Amid Liquidit...
# 2     Musk donates to super pac working to elect Tru...
# 3     US FTC issues warning to franchisors over unfa...
# 4                             Rooftop solar's dark side
# ...                                                 ...
# 3495  Arrow Electronics, Inc. (NYSE:ARW) Shares Purc...
# ...

# %%
df2 = df.drop_duplicates()

# %%
df2
# Out:
#                  Source           Author  \
# 0               stgnews   Bridger Palmer
# 1         Zimbabwe Mail   Staff Reporter
# 2             4-traders              NaN
# 3             4-traders              NaN
# 4                PLANET              NaN
# ...                 ...              ...
# 2795       etfdailynews  MarketBeat News
# 2796       etfdailynews  MarketBeat News
# 2797       etfdailynews  MarketBeat News
# 2798  finanznachrichten              NaN
# 2799       etfdailynews  MarketBeat News
#
#                                                   Title  \
# 0     Pine View High teacher wins Best in State awar...
# 1     Businesses Face Financial Strain Amid Liquidit...
# 2     Musk donates to super pac working to elect Tru...
# 3     US FTC issues warning to franchisors over unfa...
# 4                             Rooftop solar's dark side
# ...                                                 ...
# 2795  Arrow Electronics, Inc. (NYSE:ARW) Shares Purc...
# ...

# %%
df
# Out:
#                  Source           Author  \
# 0               stgnews   Bridger Palmer
# 1         Zimbabwe Mail   Staff Reporter
# 2             4-traders              NaN
# 3             4-traders              NaN
# 4                PLANET              NaN
# ...                 ...              ...
# 3495       etfdailynews  MarketBeat News
# 3496       etfdailynews  MarketBeat News
# 3497       etfdailynews  MarketBeat News
# 3498  finanznachrichten              NaN
# 3499       etfdailynews  MarketBeat News
#
#                                                   Title  \
# 0     Pine View High teacher wins Best in State awar...
# 1     Businesses Face Financial Strain Amid Liquidit...
# 2     Musk donates to super pac working to elect Tru...
# 3     US FTC issues warning to franchisors over unfa...
# 4                             Rooftop solar's dark side
# ...                                                 ...
# 3495  Arrow Electronics, Inc. (NYSE:ARW) Shares Purc...
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (2763, 9)

# %%
df.describe()
# Out:
#            Source           Author  \
# count        2763             2002
# unique        503              816
# top     4-traders  MarketBeat News
# freq          235              222
#
#                                                     Title  \
# count                                                2763
# unique                                               2336
# top     Do you have COVID? Here’s how long the CDC rec...
# freq                                                   29
#
#                                               Description  \
# count                                                2763
# unique                                               2377
# top     The U.S. Centers for Disease Control and Preve...
# freq                                                   29
#
#                                                       URL  \
# count                                                2763
# unique                                               2669
# ...

# %%
df['Sentimentos_positivos'] = df[['Sentiment']] == 'positive'

# %%
df
# Out:
#                  Source           Author  \
# 0               stgnews   Bridger Palmer
# 1         Zimbabwe Mail   Staff Reporter
# 2             4-traders              NaN
# 3             4-traders              NaN
# 4                PLANET              NaN
# ...                 ...              ...
# 2795       etfdailynews  MarketBeat News
# 2796       etfdailynews  MarketBeat News
# 2797       etfdailynews  MarketBeat News
# 2798  finanznachrichten              NaN
# 2799       etfdailynews  MarketBeat News
#
#                                                   Title  \
# 0     Pine View High teacher wins Best in State awar...
# 1     Businesses Face Financial Strain Amid Liquidit...
# 2     Musk donates to super pac working to elect Tru...
# 3     US FTC issues warning to franchisors over unfa...
# 4                             Rooftop solar's dark side
# ...                                                 ...
# 2795  Arrow Electronics, Inc. (NYSE:ARW) Shares Purc...
# ...

# %%
outro_dataframe = df[['Description', 'Sentiment', 'Type']]

# %%
outro_dataframe
# Out:
#                                             Description Sentiment        Type
# 0     ST. GEORGE — Kaitlyn Larson, a first-year teac...  positive    Business
# 1     Harare, Zimbabwe – Local businesses are grappl...   neutral    Business
# 2     (marketscreener.com) Billionaire Elon Musk has...  positive    Business
# 3     (marketscreener.com) A U.S. trade regulator on...  negative    Business
# 4     4.5 million households in the U.S. have solar ...  positive    Business
# ...                                                 ...       ...         ...
# 2795  QRG Capital Management Inc. increased its stak...  positive  Technology
# 2796  QRG Capital Management Inc. bought a new posit...  positive  Technology
# 2797  QRG Capital Management Inc. boosted its stake ...  positive  Technology
# 2798  WESTFORD, Mass., July 18, 2024 /PRNewswire/ --...   neutral  Technology
# 2799  QRG Capital Management Inc. reduced its holdin...  positive  Technology
#
# [2763 rows x 3 columns]

# %%
subset_df = outro_dataframe[1:10]

# %%
subset_df
# Out:
#                                          Description Sentiment      Type
# 1  Harare, Zimbabwe – Local businesses are grappl...   neutral  Business
# 2  (marketscreener.com) Billionaire Elon Musk has...  positive  Business
# 3  (marketscreener.com) A U.S. trade regulator on...  negative  Business
# 4  4.5 million households in the U.S. have solar ...  positive  Business
# 5  (marketscreener.com) Billionaire investor Mari...  positive  Business
# 6  (marketscreener.com) July 12, 2024 5:08 pm QWI...  positive  Business
# 7  (marketscreener.com) Rome Resources Ltd. is pl...  positive  Business
# 8  Business Reporter A POTENTIALLY bruising fight...  positive  Business
# 9  With creative strategies and deep industry kno...  positive  Business

# %%
df.shape
# Out:
# (2763, 10)

# %%
outro_dataframe.shape
# Out:
# (2763, 3)

# %%
novo_dataframe = pd.concat([df, outro_dataframe])

# %%
novo_dataframe.shape
# Out:
# (5526, 10)

# %%
novo_dataframe.drop_duplicates(inplace=True)

# %%
novo_dataframe.shape
# Out:
# (5232, 10)
